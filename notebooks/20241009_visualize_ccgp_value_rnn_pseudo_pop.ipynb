# %% [markdown]
# ### Visualize results from running CCGP on Value Outputs of an RNN, when simulating pseudo populations

# %%
# %load_ext autoreload
# %autoreload 2

import os
import numpy as np
import pandas as pd
import utils.behavioral_utils as behavioral_utils
import utils.information_utils as information_utils
import utils.visualization_utils as visualization_utils
import utils.pseudo_classifier_utils as pseudo_classifier_utils
import utils.classifier_utils as classifier_utils

import utils.io_utils as io_utils

import utils.glm_utils as glm_utils
from matplotlib import pyplot as plt
import matplotlib
import utils.spike_utils as spike_utils
import utils.subspace_utils as subspace_utils
from trial_splitters.condition_trial_splitter import ConditionTrialSplitter 
from utils.session_data import SessionData
from constants.behavioral_constants import *


import scipy

# %%
OUTPUT_DIR = "/data/patrick_res/rl/pseudo_pop/res/"

# %%
# within_cond_acc = np.load(os.path.join(OUTPUT_DIR, f"shared_belief_rnn_prob_matches_sam_0_within_cond_accs.npy")).reshape(-1)
# across_cond_acc = np.load(os.path.join(OUTPUT_DIR, f"shared_belief_rnn_prob_matches_sam_0_across_cond_accs.npy")).reshape(-1)

within_cond_acc = np.load(os.path.join(OUTPUT_DIR, f"separate_belief_rnn_prob_matches_sam_noise_idx_6_within_cond_accs.npy")).reshape(-1)
across_cond_acc = np.load(os.path.join(OUTPUT_DIR, f"separate_belief_rnn_prob_matches_sam_noise_idx_6_across_cond_accs.npy")).reshape(-1)

# %%
fig, ax = plt.subplots()
visualization_utils.visualize_accuracy_bars([within_cond_acc, across_cond_acc], ["Within Condition", "Across Condition"], ax)
ax.set_ylabel("Decoding Accuracy")
ax.set_title("CCGP of Value Output from RNN Pseudo-pop (Shared belief RNN)")
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:166: FutureWarning: Setting a gradient palette using color= is deprecated and will be removed in version 0.13. Set `palette='dark:0'` for same effect.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 8.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1.0, 'CCGP of Value Output from RNN Pseudo-pop (Shared belief RNN)')
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 8.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
