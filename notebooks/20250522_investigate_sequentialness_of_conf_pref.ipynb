# %% [markdown]
# ### Decoder weights for sequential-ness of conf/pref representations
# https://www.notion.so/walkerlab/Decoder-weights-for-sequential-ness-of-conf-pref-representations-1fb2dc9f9992803798c3e610ad7b3600

# %%
# %load_ext autoreload
# %autoreload 2

import os
import numpy as np
import pandas as pd
import utils.behavioral_utils as behavioral_utils
import utils.information_utils as information_utils
import utils.visualization_utils as visualization_utils
import utils.pseudo_classifier_utils as pseudo_classifier_utils
import utils.classifier_utils as classifier_utils

import utils.io_utils as io_utils

import utils.glm_utils as glm_utils
from matplotlib import pyplot as plt
import matplotlib
import utils.spike_utils as spike_utils
import utils.subspace_utils as subspace_utils
from trial_splitters.condition_trial_splitter import ConditionTrialSplitter 
from utils.session_data import SessionData
from constants.behavioral_constants import *
from constants.decoding_constants import *
import seaborn as sns
from scripts.pseudo_decoding.belief_partitions.belief_partition_configs import *
import scripts.pseudo_decoding.belief_partitions.belief_partitions_io as belief_partitions_io

import scipy
import argparse
import copy

# %% [markdown]
# ### SA, 95th, conf ordering for pref

# %%
args = argparse.Namespace(
    **BeliefPartitionConfigs()._asdict()
)
args.subject = "SA"
args.beh_filters = {"Response": "Correct", "Choice": "Chose"}
args.shuffle_method = "session_permute"
args.sig_unit_level = "belief_partition_all_time_95th"

args.mode = "conf"
ordering = visualization_utils.plot_weights(args, region_level="structure_level2")

args.mode = "pref"
ordering = visualization_utils.plot_weights(args, region_level="structure_level2", unit_orders=ordering)

# %% [markdown]
# ### SA, 95th, pref ordering for conf

# %%
args = argparse.Namespace(
    **BeliefPartitionConfigs()._asdict()
)
args.subject = "SA"
args.beh_filters = {"Response": "Correct", "Choice": "Chose"}
args.shuffle_method = "session_permute"
args.sig_unit_level = "belief_partition_all_time_95th"

args.mode = "pref"
ordering = visualization_utils.plot_weights(args, region_level="structure_level2")

args.mode = "conf"
ordering = visualization_utils.plot_weights(args, region_level="structure_level2", unit_orders=ordering)

# %% [markdown]
# ### BL, 95th, conf ordering for pref

# %%
args = argparse.Namespace(
    **BeliefPartitionConfigs()._asdict()
)
args.subject = "BL"
args.beh_filters = {"Response": "Correct", "Choice": "Chose"}
args.shuffle_method = "session_permute"
args.sig_unit_level = "belief_partition_all_time_95th"

args.mode = "conf"
ordering = visualization_utils.plot_weights(args)

args.mode = "pref"
ordering = visualization_utils.plot_weights(args, unit_orders=ordering)

# %% [markdown]
# ### BL, 95th, pref ordering for conf

# %%
args = argparse.Namespace(
    **BeliefPartitionConfigs()._asdict()
)
args.subject = "BL"
args.beh_filters = {"Response": "Correct", "Choice": "Chose"}
args.shuffle_method = "session_permute"
args.sig_unit_level = "belief_partition_all_time_95th"

args.mode = "pref"
ordering = visualization_utils.plot_weights(args)

args.mode = "conf"
ordering = visualization_utils.plot_weights(args, unit_orders=ordering)
