# %%
import pandas as pd
from constants.behavioral_constants import *

# %%
sub = "SA"
sess = "20180802"
saccades = pd.read_csv(f"/data/rawdata/sub-{sub}/sess-{sess}/behavior/sub-{sub}_sess-{sess}_saccades.csv")

# %%
saccades
# Out:
#        Unnamed: 0  trial interval obj_start obj_end   distance   direction  \
# 0               0     -1  no_task         -       -  16.795634  129.228218
# 1               1     -1  no_task         -       -   6.968668  134.493032
# 2               2     -1  no_task         -       -  41.406025 -144.198704
# 3               3     -1  no_task         -       -  18.318783   -0.190063
# 4               4     -1  no_task         -       -  27.194048    0.000823
# ...           ...    ...      ...       ...     ...        ...         ...
# 42993       42993     -1  no_task         -       -  18.890329  -84.914835
# 42994       42994     -1  no_task         -       -  22.769532 -174.300451
# 42995       42995     -1  no_task         -       -   0.353903 -164.468190
# 42996       42996     -1  no_task         -       -  24.117217    6.411905
# 42997       42997     -1  no_task         -       -  46.638407 -153.513396
#
# ...

# %%
saccades.obj_end.unique()
# Out:
# array(['-', 'h0', 'h1', 'h2', 'h3', 's0', 's2', 's1', 's3', 'n', 's0_s3',
#        's2_s3', 's1_s2', 'h1_s3', 'h2_s3', 'h0_s3', 'h0_s1'], dtype=object)

# %%
beh = pd.read_csv(f"/data/rawdata/sub-SA/sess-{sess}/behavior/sub-SA_sess-{sess}_object_features.csv")

# %%
beh["Item0Pattern"]
# Out:
# 0         RIPPLE
# 1         RIPPLE
# 2         RIPPLE
# 3         RIPPLE
# 4         RIPPLE
#           ...
# 1757       SWIRL
# 1758      RIPPLE
# 1759      RIPPLE
# 1760    POLKADOT
# 1761       SWIRL
# Name: Item0Pattern, Length: 1762, dtype: object
